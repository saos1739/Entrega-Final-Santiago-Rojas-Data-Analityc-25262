# %% [markdown]
# # 📘 Entrega Final
#
#
# **Nombre del alumno:** Rojas Casas Santiago
#
#
# ### Mapeo a la rúbrica
# ###Etapa 1: Recopilación y Preparación de Datos
# 1. 1-Crear un documento en Google Colaboratory y cargar los sets de datos como DataFrames.
# 4. 4-Introducción a Pandas: realizar un análisis exploratorio inicial de los DataFrames.
# 5. 5-Calidad de Datos: Identificar valores nulos y duplicados en los conjuntos de datos. Documentar el estado inicial de los datos.
# ###Etapa 2: Preprocesamiento y Limpieza de Datos
# 1. Limpieza de Datos: Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados. Documentar el proceso y los resultados.
# 2. Transformación de Datos: Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.
# 3. Agregación: Resumir las ventas por categoría de producto y analizar los ingresos generados.
# 4. Integración de Datos: Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.
# ###Etapa 3: Análisis de Datos
# 1. Estadística Descriptiva: Calcular medidas de tendencia central y dispersión sobre las ventas. Presentar los resultados en un informe.
# 2. Análisis Exploratorio de Datos (EDA): Realizar un análisis exploratorio utilizando visualizaciones para identificar patrones y tendencias en las ventas.
# 3. Correlación: Evaluar la relación entre diferentes variables (por ejemplo, precio y cantidad vendida) y mostrar los resultados en un gráfico.
# ###Etapa 4: Visualización de Datos
# 1. Visualización con Matplotlib: Crear gráficos básicos (líneas, barras, dispersión)
# 2. Visualización Avanzada con Seaborn: Desarrollar visualizaciones estadísticas avanzadas, utilizando paletas y estilos para mejorar la presentación.
# 4. Presentación Final: Preparar una presentación que resuma los hallazgos, insights y visualizaciones generadas a lo largo del proyecto.
# # Sección nueva

# %% [markdown]
# ## 🧩 Etapa 1: Recopilación y Preparación de Datos
# **Objetivo:** Demostrar habilidades en Python, familiaridad con el entorno de trabajo y conocimientos básicos sobre manipulación de datos.

# %% [markdown]
# *texto en cursiva*### 1️⃣ Carga de datos

# %%
import pandas as pd
import numpy as np

# %%
#montamos el drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#verificamos los datasets

import os
os.listdir(r"/content/drive/MyDrive/datasets")
# Out:
# ['ventas.csv',
#  'clientes.csv',
#  'marketing.csv',
#  'marketing_clean.csv',
#  'ventas_clean.csv',
#  'clientes_clean.csv']

# %%
#verificamos las rutas

ruta_ventas = "/content/drive/MyDrive/datasets/ventas.csv"
ruta_cliente = "/content/drive/MyDrive/datasets/clientes.csv"
ruta_marketing = "/content/drive/MyDrive/datasets/marketing.csv"

#creamos los dataframes

ventas = pd.read_csv(ruta_ventas)
clientes = pd.read_csv(ruta_cliente)
marketing = pd.read_csv(ruta_marketing)

#verificamos si se cargaron de forma correcta

print("ventas.shape ->", ventas.shape)
print("clientes.shape ->", clientes.shape)
print("marketing.shape ->", marketing.shape)

#mostramos las primeras 5 columnas de cada dataset

display(ventas.head(5))
display(clientes.head(5))
display(marketing.head(5))
# Out:
# ventas.shape -> (3035, 6)
# clientes.shape -> (567, 5)
# marketing.shape -> (90, 6)
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# ...

# %% [markdown]
# ### 2️⃣ Análisis exploratorio inicial

# %%
# TODO: Realizar un análisis exploratorio inicial de los DataFrames.
# Sugerencia: usar métodos como .info(), .describe(), .shape y .columns. dtypes.
# Esto te ayudará a entender la estructura y el contenido de los datos.
# Podés incluir comentarios sobre observaciones iniciales.


def eda(df, nombre):
    print(f"=== {nombre} ===") #MUESTRA ENCABEZADO
    print("shape:", df.shape) #DEVUELVE UNA TUPLA CON EL NUMERO DE FILAS Y COLUMNAS
    print("columnas:", list(df.columns)) #Muestra una lista con el nombre de las columans
    print("dtypes:")
    print(df.dtypes) #Muestra el tipo de datos de cada columna
    print("\nNulos por columna:")
    print(df.isna().sum()) #Muestra la cantidad de valores Nulos
    print("\nPrimeras filas:")
    display(df.head(5)) # Muestra las primeras 5 filas de los DF
    print("\nDescribe (numérico):")
    display(df.describe(include='number')) #genera una descripcion de las columnas numericas
    print("-"*100)

# %%
eda(ventas, 'Ventas(inicial)')
# Out:
# === Ventas(inicial) ===
# shape: (3035, 6)
# columnas: ['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta', 'categoria']
# dtypes:
# id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
#
# Nulos por columna:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# Primeras filas:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# ...

# %%
eda(clientes, 'Clientes(inicia)')
# Out:
# === Clientes(inicia) ===
# shape: (567, 5)
# columnas: ['id_cliente', 'nombre', 'edad', 'ciudad', 'ingresos']
# dtypes:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
#
# Nulos por columna:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
#
# Primeras filas:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65
# Describe (numérico):
#        id_cliente        edad      ingresos
# count  567.000000  567.000000    567.000000
# mean   284.000000   37.940035  34668.739012
# ...

# %%
eda(marketing, 'Marketing(inicial)')
# Out:
# === Marketing(inicial) ===
# shape: (90, 6)
# columnas: ['id_campanha', 'producto', 'canal', 'costo', 'fecha_inicio', 'fecha_fin']
# dtypes:
# id_campanha       int64
# producto         object
# canal            object
# costo           float64
# fecha_inicio     object
# fecha_fin        object
# dtype: object
#
# Nulos por columna:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
#
# Primeras filas:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024
# Describe (numérico):
#        id_campanha      costo
# ...

# %% [markdown]
# ### 3️⃣ Calidad de los datos

# %%
# TODO: Identificar valores nulos y duplicados en los conjuntos de datos.
# Sugerencia: usar .isna().sum() y .duplicated().sum().
# Documentar las observaciones con print() o comentarios.

def calidad(df, nombre, clave= None):
  print(f"=== {nombre} ===") #imprime el nombre de la columna
  print("Nulos por columna:")
  display(df.isna().sum().to_frame('nulos'))# crea un DF y suma los valores Nulos y los coloca en una columna nueva llamada Nulos



  dup_rows = df.duplicated(keep=False).sum() #marca todas las filas que tienen otra  igual en el DF y luego cuenta las que estan repetidas
  print(f'La cantidad de filas duplicadas es: {dup_rows}')

# %%
#ejecutamos la funcion

calidad(ventas, 'Ventas(calidad)')
# Out:
# === Ventas(calidad) ===
# Nulos por columna:
#              nulos
# id_venta         0
# producto         0
# precio           2
# cantidad         2
# fecha_venta      0
# categoria        0
# La cantidad de filas duplicadas es: 70

# %% [markdown]
# ## 🧹 Etapa 2: Preprocesamiento y Limpieza de Datos
# **Objetivo:** Demostrar conocimiento de las técnicas de limpieza y transformación de datos.

# %% [markdown]
# ### 4️⃣ Limpieza de datos

# %%
# TODO: Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados.
# Sugerencia: aplicar .drop_duplicates(), .str.strip(), .str.replace() según el caso.
# Documentar el proceso y los resultados.

#creamos las copias de los datasets originales

ventas_clean = ventas.copy()
clientes_clean = clientes.copy()
marketing_clean = marketing.copy()

#eliminamos las filas duplicadas

ventas_clean = ventas_clean.drop_duplicates()
clientes_clean = clientes_clean.drop_duplicates()
marketing_clean = marketing_clean.drop_duplicates()

# %%
#comprobamos que se haya realizado de forma correcta,

calidad(ventas_clean, 'Ventas(calidad)')
calidad(clientes_clean, 'Clientes(ingresos)')
calidad(marketing_clean, 'Marketing(producto)')

#hay 0 filas duplicadas, asi que se realizo de forma correcta
# Out:
# === Ventas(calidad) ===
# Nulos por columna:
#              nulos
# id_venta         0
# producto         0
# precio           2
# cantidad         2
# fecha_venta      0
# categoria        0
# La cantidad de filas duplicadas es: 0
# === Clientes(ingresos) ===
# Nulos por columna:
#             nulos
# id_cliente      0
# nombre          0
# edad            0
# ciudad          0
# ingresos        0
# La cantidad de filas duplicadas es: 0
# === Marketing(producto) ===
# Nulos por columna:
#               nulos
# id_campanha       0
# producto          0
# canal             0
# costo             0
# fecha_inicio      0
# fecha_fin         0
# La cantidad de filas duplicadas es: 0

# %%
# Normalizamos todo lo que sea texto con la funcion normalizar

def normalizar(df):
  for col in df.select_dtypes(include='object').columns:  # Filtramos el DF y nos quedamos con las columnas con Object
    df[col] = df[col].astype(str).str.strip().str.replace(r"[\u200b\t\r\n]", "", regex=True).str.replace(" +", " ", regex=True).str.title()  #selecciona la columna actual y combierte el tipo de dato a string, borra los espacios en blanco o caracteres invisibles

  return df

  #normalizamos las fechas

for df in [ventas_clean, clientes_clean, marketing_clean]: #itera en cada df
  for col in df.columns: #itera en cada column
    if 'fecha' in col.lower(): #Busca las columnas con Fecha
      df[col]= pd.to_datetime(df[col], errors= 'coerce', dayfirst=True) #cambia el formato de las fechas a DD/MM/YY

# %%
#aplicamos la funcion
ventas_clean = normalizar(ventas_clean)
clientes_clean = normalizar(clientes_clean)
marketing_clean = normalizar(marketing_clean)

display(ventas_clean)
display(clientes_clean)
display(marketing_clean)
# Out:
#       id_venta                producto   precio  cantidad fecha_venta  \
# 0          792       Cuadro Decorativo   $69.94       5.0  2024-01-02
# 1          811         Lámpara De Mesa  $105.10       5.0  2024-01-02
# 2         1156                Secadora   $97.96       3.0  2024-01-02
# 3         1372                Heladera  $114.35       8.0  2024-01-02
# 4         1546                Secadora  $106.21       4.0  2024-01-02
# ...        ...                     ...      ...       ...         ...
# 3030      1837         Horno Eléctrico  $104.12       9.0  2024-12-30
# 3031      2276                  Laptop   $85.27       9.0  2024-12-30
# 3032      2696                  Laptop  $107.81       4.0  2024-12-30
# 3033      2913              Smartphone   $99.85       7.0  2024-12-30
# 3034      2930  Consola De Videojuegos   $55.47       6.0  2024-12-30
#
#               categoria
# 0            Decoración
# 1            Decoración
# 2     Electrodomésticos
# 3     Electrodomésticos
# ...

# %%
#Normalizamos los valores numerios

if 'precio' in ventas.columns:
  ventas_clean['precio'] = ventas_clean['precio'].astype(str).str.replace('$', '', regex=False).str.replace(',', '') # Primero convierte todo a texto, luego reemplaza los $ y los remplaza por espacios vacios, luego elimina todas las comas y quita los espacios sobrantes
  ventas_clean['precio'] = pd.to_numeric(ventas_clean['precio'], errors='coerce') # Convierte el texto a numero

# %%
print(ventas_clean.dtypes)
# Out:
# id_venta                int64
# producto               object
# precio                float64
# cantidad              float64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object

# %%
#nomalizamos Cantidad

if 'cantidad' in ventas_clean.columns:
  ventas_clean['cantidad'] = pd.to_numeric(ventas_clean['cantidad'], errors='coerce').astype('Int64') #Esto cambia el tipo de valor para que permita valores nulos

print(ventas_clean.dtypes)
# Out:
# id_venta                int64
# producto               object
# precio                float64
# cantidad                Int64
# fecha_venta    datetime64[ns]
# categoria              object
# dtype: object

# %%
#guardamos los DF como CSV

ventas_clean.to_csv('/content/drive/MyDrive/datasets/ventas_clean.csv', index=False)
clientes_clean.to_csv('/content/drive/MyDrive/datasets/clientes_clean.csv', index=False)
marketing_clean.to_csv('/content/drive/MyDrive/datasets/marketing_clean.csv', index=False)

# %%
def filtro_rendimiento(dfs, nombres):
  resumen = []

  for df, nombres in zip(dfs, nombres):
    nulos = df.isna().sum().sum()
    duplicados = df.duplicated(keep= False).sum()
    col = len(df.columns)
    filas = len(df)
    resumen.append({"dataset": nombres,"filas": filas,"columna": col,"cant Nulos": nulos,"cant Duplicados": duplicados})

  report = pd.DataFrame(resumen)
  #print(report)
  return report

display(filtro_rendimiento([ventas_clean, clientes_clean, marketing_clean], ['ventas', 'clientes', 'marketing']))
# Out:
#      dataset  filas  columna  cant Nulos  cant Duplicados
# 0     ventas   3000        6           4                0
# 1   clientes    567        5           0                0
# 2  marketing     90        6           0                0

# %% [markdown]
# ### 5️⃣ Transformación de datos

# %%
# TODO: Aplicar filtros y transformaciones para crear una tabla de ventas
# que muestre solo los productos con alto rendimiento. calcular el percentil 80
# y filtrar los productos que superen ese umbral en ventas.
#quantile(0.8)
# Sugerencia: usar .query() o condiciones con operadores lógicos.


def encontrar_columna(df, candidatos): #buscamos la columna
  for col in df.columns: #iteramos
    nombre = col.lower() #lower convierte todo a minuscula
    if any(candidato in nombre for candidato in candidatos): #si se cumple la condicion, nos devuelve el nombre de la columna
      return col
  return None #en caso contrario nos devuelve None

# %%
#probamos la funcion

Product_col = encontrar_columna(ventas_clean, ['producto', 'precio'])
print(f'la columna es:', Product_col)
# Out:
# la columna es: producto

# %%
# Calculamos el ingreso

ventas_perf = ventas_clean.assign(ingresos = ventas_clean['precio'] * ventas_clean['cantidad'])
print(ventas_perf.head(5))
# Out:
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro Decorativo   69.94         5  2024-01-02
# 1       811    Lámpara De Mesa  105.10         5  2024-01-02
# 2      1156           Secadora   97.96         3  2024-01-02
# 3      1372           Heladera  114.35         8  2024-01-02
# 4      1546           Secadora  106.21         4  2024-01-02
#
#            categoria  ingresos
# 0         Decoración     349.7
# 1         Decoración     525.5
# 2  Electrodomésticos    293.88
# 3  Electrodomésticos     914.8
# 4  Electrodomésticos    424.84

# %%
# Agregamos metricas

resumen_pro = ( ventas_perf.groupby(by= Product_col, dropna = False, as_index = False, observed = False).agg(ingreso_total=('ingresos', 'sum'),precio_promedio=('precio', 'mean'), unidades=('cantidad', 'sum'), registros=('ingresos', 'size')))

# %%
print(resumen_pro.head(15))
# Out:
#                   producto  ingreso_total  precio_promedio  unidades  \
# 0          Adorno De Pared       48093.49        76.097800       633
# 1                 Alfombra       44773.06        74.098300       615
# 2               Aspiradora       50085.86        77.447400       651
# 3              Auriculares       74175.58        76.302727       958
# 4                 Batidora        50979.2        77.537200       672
# 5                 Cafetera       59607.31        79.046581       765
# 6               Candelabro        11128.8        74.595417       160
# 7   Consola De Videojuegos       46174.41        76.346869       623
# 8                 Cortinas       44865.03        73.649900       610
# 9        Cuadro Decorativo        54297.6        74.578000       726
# 10          Cámara Digital       45217.96        72.010700       638
# 11   Elementos De Cerámica       45411.09        71.611515       636
# 12       Espejo Decorativo       46783.31        75.663300       635
# ...

# %%
# Calculamos el percentil
p80 = resumen_pro['ingreso_total'].quantile(0.8, interpolation='linear')
print(f"{p80:,.2f}")
# Out:
# 52,518.85

# %%
#Filtramos los productos de alto rendimiento

ventas_top = resumen_pro.query(f'ingreso_total >= @p80', engine = "python").sort_values(['ingreso_total', 'registros'], ascending= [False, False], na_position='last', ignore_index= False )

print(f"Columna de producto detectada: {Product_col}")
print(f"percentil 80 de ingreso_total: {float(p80):,.2f}")
print("Productos de ALTO RENDIMIENTO:")
display(ventas_top.head(20))
# Out:
# Columna de producto detectada: producto
# percentil 80 de ingreso_total: 52,518.85
# Productos de ALTO RENDIMIENTO:
#              producto  ingreso_total  precio_promedio  unidades  registros
# 19    Lámpara De Mesa       82276.38        72.720625      1112        176
# 3         Auriculares       74175.58        76.302727       958        143
# 20         Microondas       72562.89        79.176000       912        135
# 5            Cafetera       59607.31        79.046581       765        117
# 9   Cuadro Decorativo        54297.6        74.578000       726        100
# 26         Smartphone       54132.44        81.398416       665        101

# %% [markdown]
# ### 6️⃣ Agregación

# %%
# TODO: Resumir las ventas por categoría de producto y analizar los ingresos generados.
# Sugerencia: usar .groupby() y .agg() para generar métricas como suma y promedio.

def encontrar_columna(df, candidatos):
  for c in df.columns:
    if any(p in c.lower()  for p in candidatos):
      return c
  return None

#detectamos categoria
cat_col = encontrar_columna(ventas_clean, ['categoria'])
print(f'la columna es:', cat_col)

#Detectamos la columna ingreso

if 'ingresos' not in ventas_clean.columns:
  ventas_cat = ventas_clean.assign(ingresos = ventas_clean["precio"] * ventas_clean["cantidad"])
else:
    ventas_cat = ventas_clean.copy()


#Realizamos la agregacion

resumen_cat = (ventas_cat.groupby(by= cat_col, dropna= False, as_index= False)
               .agg(ingreso_total=('ingresos', 'sum'),
                    unidades=('cantidad', 'sum'),
                    ventas=('ingresos', 'size'),
                    precio_promedio=('precio', 'mean')))

resumen_cat = resumen_cat.sort_values(by='ingreso_total',ascending=False,na_position='last',ignore_index=True )

display(resumen_cat)
# Out:
# la columna es: categoria
#            categoria  ingreso_total  unidades  ventas  precio_promedio
# 0  Electrodomésticos      505299.63      6592    1000         76.52096
# 1        Electrónica       482577.8      6413     999         75.25492
# 2         Decoración      479216.09      6490    1001         74.09800

# %% [markdown]
# ### 7️⃣ Integración de datos, opcional, NO OBLIGATORIO

# %%
#agrupo el df de ventas clean por producto y sum la cantidad por el precio
df_ventas_x_producto = ventas_clean.groupby('producto').agg(
    precio_por_cantidad=('precio', lambda x: (x * ventas_clean.loc[x.index, 'cantidad']).sum())
)

# Ordeno por producto de forma ascendente
df_ventas_x_producto = df_ventas_x_producto.sort_values(by='producto', ascending=True)

# muestro resultado
display(df_ventas_x_producto)
# Out:
#                         precio_por_cantidad
# producto
# Adorno De Pared                    48093.49
# Alfombra                           44773.06
# Aspiradora                         50085.86
# Auriculares                        74175.58
# Batidora                           50979.20
# Cafetera                           59607.31
# Candelabro                         11128.80
# Consola De Videojuegos             46174.41
# Cortinas                           44865.03
# Cuadro Decorativo                  54297.60
# Cámara Digital                     45217.96
# Elementos De Cerámica              45411.09
# Espejo Decorativo                  46783.31
# Freidora Eléctrica                 50155.15
# Heladera                           25736.80
# Horno Eléctrico                    49913.90
# Jarrón Decorativo                  51130.88
# Laptop                             46179.48
# Lavadora                           48946.44
# Lámpara De Mesa                    82276.38
# ...

# %% [markdown]
# ##ETAPA 3: 1. Estadística Descriptiva

# %% [markdown]
# ###Calcular medidas de tendencia central y dispersión sobre las ventas. Presentar los resultados en un informe.

# %%
import matplotlib.pyplot as plt

# %%
# Preparación de datos
df = resumen_pro.copy()
df_ordenado = df.sort_values("ingreso_total", ascending=False)

# Configuración de estilo y figura usando 'subplots' (Estándar profesional)
fig, ax = plt.subplots(figsize=(12, 10))
color_barra = "#386FC7"

# Crear las barras
barras = ax.bar(df_ordenado["producto"], df_ordenado["ingreso_total"], color=color_barra)

# Títulos y etiquetas
ax.set_title("Ingresos Totales por Producto", fontsize=14, weight="bold")
ax.set_xlabel("Producto", fontsize=12)
ax.set_ylabel("Ingreso Total ($)", fontsize=12)

# Rotación de etiquetas del eje X
ax.tick_params(axis='x', rotation=90)

# --- MEJORA PRINCIPAL ---
# Usamos 'bar_label' en lugar de un bucle manual para las etiquetas.
# label_type='center' coloca el texto en el medio de la barra.
ax.bar_label(
    barras,
    labels=[f"${x:,.0f}" for x in df_ordenado["ingreso_total"]], # Formato moneda
    label_type='center',
    color='white',
    fontsize=9,
    rotation=90
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ###GRAFICO DE RESUMEN POR CATEGORIA

# %%
import matplotlib.pyplot as plt

df = resumen_cat.copy()

df_ordenado = df.sort_values("ingreso_total", ascending=False)

#configuramos el grafico
plt.figure(figsize=(12, 10))
color_barra = "#386FC7"
barras = plt.bar(df_ordenado["categoria"], df_ordenado["ingreso_total"], color=color_barra)

#titulo para el grafico
plt.title("Ingresos Totales por Categoria", fontsize=14, weight="bold")
plt.xlabel("Categoria", fontsize=14)
plt.ylabel("Ingreso Total ($)", fontsize=14)

#Decoramos el grafico
plt.xticks(rotation=90)

#colocamos el valor en cada barra

for barra in barras:
  y = barra.get_height()
  plt.text(barra.get_x() + barra.get_width() / 2, y / 2, f"${y:,.0f}", ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
media = df['ingreso_total'].mean()
mediana = df['ingreso_total'].median()
moda = df['ingreso_total'].mode()

print("Media:", media)
print("Mediana:", mediana)
print("Moda:")
print(moda)
# Out:
# Media: 489031.17333333334
# Mediana: 482577.8
# Moda:
# 0    479216.09
# 1     482577.8
# 2    505299.63
# Name: ingreso_total, dtype: Float64

# %%
q1 = df['ingreso_total'].quantile(0.25)
q2 = df['ingreso_total'].quantile(0.5)
q3 = df['ingreso_total'].quantile(0.75)
iqr = q3 - q1

print("Q1:", q1)
print("Mediana (Q2):", q2)
print("Q3:", q3)
print("IQR:", iqr)
# Out:
# Q1: 480896.945
# Mediana (Q2): 482577.8
# Q3: 493938.71499999997
# IQR: 13041.76999999996

# %%
lim_inf = q1 - 1.5 * iqr
lim_sup = q3 + 1.5 * iqr

outliers = df[(df['ingreso_total'] < lim_inf) | (df['ingreso_total'] > lim_sup)]

print("Límite inferior:", lim_inf)
print("Límite superior:", lim_sup)
print("\nOutliers detectados:")
print(outliers)
# Out:
# Límite inferior: 461334.29000000004
# Límite superior: 513501.3699999999
#
# Outliers detectados:
# Empty DataFrame
# Columns: [categoria, ingreso_total, unidades, ventas, precio_promedio]
# Index: []

# %% [markdown]
# ###ETAPA 3: 2. Análisis Exploratorio de Datos (EDA): Realizar un análisis exploratorio utilizando visualizaciones para identificar patrones y tendencias en las ventas.

# %%
#Importamos matplotlib

import matplotlib

vals = resumen_pro['ingreso_total'].dropna() #selecciono la culumna de ingreso total y borro los valores vacios y los NaN

#creamos el grafico

plt.figure(figsize=(15,9)) #configuramos el tamaño
plt.boxplot(vals, vert= False)  #definimos que el garfico sea en horizontal
plt.title('Dispersion de ingreso_total por productos')
plt.ylabel('ingreso total  ($)')
plt.tight_layout()  #ajusta margenes
plt.show()

# %%
#Histograma de la distribucion
import seaborn as sns
plt.figure(figsize= (10,8))#configuramos el tama;o del grafico
sns.histplot(vals, kde= True)  #crea un histograma, y configuramos para que muestre la curva sobre las barras del histograma
plt.title('Distribucion del ingreso total por productos')
plt.xlabel('Ingreso total ($)')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ###Etapa 3: 3 Correlación
# Evaluamos la relación entre precio_promedio y unidades por producto. Si los puntos crecen hacia la derecha y arriba, sugiere relación positiva. También mostramos el coeficiente de correlación.

# %%
# calculamos el coeficiente de correlacion

corr_val = resumen_pro[['precio_promedio','unidades']].corr().loc['precio_promedio','unidades']  #corr calcula la matriz de correlacion entre  precio promedio y unidades
print(f"Coeficiente de correlacion: {corr_val:.2f}")
# Out:
# Coeficiente de correlacion: 0.22

# %%
import matplotlib.pyplot as plt

x = resumen_pro['precio_promedio']  # precio promedio por producto
y = resumen_pro['unidades']  # unidades vendidas por producto

plt.figure(figsize=(10, 6))  # Configuramos el tamaño del gráfico
plt.scatter(x, y) #graficos por puntos
plt.title('Relación entre el Precio Promedio y las Unidades Vendidas')
plt.xlabel('Precio Promedio')
plt.ylabel('Unidades Vendidas')
plt.tight_layout()

# %%
#calculamos la correlacion

corr_val = resumen_pro[['precio_promedio','unidades']].corr().loc['precio_promedio','unidades'] #corr calcula la matriz de correlacion de una tabla 2x2 entre precio promedio y unidades
print(f"Coeficiente de correlación (Pearson): {corr_val:.3f}")

# Interpretación simple:
if corr_val > 0.8:
    print("Interpretación: relación positiva clara (a mayor precio_promedio, suelen venderse más unidades).")
elif corr_val > 0.2:
    print("Interpretación: relación positiva débil a moderada.")
elif corr_val < -0.8:
    print("Interpretación: relación negativa clara (a mayor precio_promedio, suelen venderse menos unidades).")
elif corr_val < -0.3:
    print("Interpretación: relación negativa débil a moderada.")
else:
    print("Interpretación: relación muy débil o nula.")
# Out:
# Coeficiente de correlación (Pearson): 0.217
# Interpretación: relación positiva débil a moderada.

# %% [markdown]
# ## Etapa 4: Visualización de Datos

# %% [markdown]
# ### ETAPA 4.1 Visualización con Matplotlib (básica)
# Gráficos de **líneas, barras y dispersión** comentados línea por línea.

# %%
import matplotlib.pyplot as plt  # importamos la librería de gráficos

#barras x ingreso de producto

df= resumen_pro.copy()  #copiamos el df para no modificar el original
df_ordenado = df.sort_values("ingreso_total", ascending=False) #ordenamos de forma descendiente

#configuramos el grafico

plt.figure(figsize=(12, 10))
barras = plt.bar(df_ordenado["producto"], df_ordenado["ingreso_total"])
plt.title('Ingresos Totales por Producto')
plt.xlabel('Producto')
plt.ylabel('Ingreso Total ($)')
plt.xticks(rotation=90) # rotamos las etiquetas del eje x

for b in barras:
  h = b.get_height()
  x_c = b.get_x() + b.get_width()/2
  plt.text(x_c, h/2, f"${h:,.0f}", ha='center', va='center', rotation=90)

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np


#grafico con linea de tendencia

valores = resumen_pro['ingreso_total'].sort_values()
acum = np.cumsum(valores)

#configuramos grafico

plt.figure(figsize = (12,6))
plt.plot(acum) # Corrected typo: pot to plot
plt.title('tendencia acumulada de ingresos')
plt.xlabel('Producto')
plt.ylabel('Ingreso Total ($)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### ETAPA 4.2 Visualización Avanzada con Seaborn
# Seaborn ofrece estilos y elementos estadísticos que mejoran la presentación

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.set_theme(style= 'whitegrid')

#barras ordenadas

df = resumen_pro.sort_values('ingreso_total', ascending=False)
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=df, x='producto', y='ingreso_total')
ax.set_title('Ingresos Totales por Producto con Seaborn')
ax.set_xlabel('Producto'); ax.set_ylabel('Ingreso Total ($)')
plt.xticks(rotation=90)



plt.tight_layout(); plt.show()

# %% [markdown]
# ### ETAPA 4.3 Presentación Final
# Escribí un informe breve que resuma:
# - **Productos líderes** y **categorías destacadas**.
# - Diferencia **media vs. mediana** y su interpretación en estos datos.
# - Presencia de **outliers** y su impacto.
# - Recomendaciones sobre **qué productos potenciar** y **eficiencia de marketing**.

# %% [markdown]
# En la primeras dos etapas realizamos la recoleccion de datos con los datasets de ventas, productos y marketing, realizando asi la limpieza de los datos nulos y duplicados, la normalizacion de los textos y los calculos del ingreso total

# %% [markdown]
# En la tercera etapa se realizaron las estadisticas decriptivas y los EDA.
#
# Llegamos a estos resultados:
#
#
#
#
# *  Ingreso total (Media): $51.000
#   Es el ingreso romedi del producto, se ve representada tamben por otros articulo
#
#
# *  Ingreso total (Mediana): $48.000
# Es el punto medio de la distribucion
#
#
#
# *  Desviacion estandar: ~$10.000
# Indica los ingresos que presentan una variabilidad moderadam osea, los productors se diferencian entre si en su rendimiento
#
#
# * Rango intercuartilico: Con esto identificamos los productors outliers positivos

# %%
EDA

*  El histograma demuesta que la distribucion sesgada a la derecha, donde los precios rondan entre los $40.000, y $50.000

*  Con el Boxplot confirmamos la dispersion y vemos los outliers positivos, entre ellos la Lampara de mensa, los auriculares, el micrronda y la Cafetera

# %% [markdown]
# Visualizacion de resultados
#
# * Con el grafico de barras vemos que los productos mas vendidos fueron: Lamparada de mesa, auriculares y por ultimo el microondas
#
# *  Los productos de Electrodomesticos y la Decoracion son las principales ventas
